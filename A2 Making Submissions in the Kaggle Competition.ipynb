# %% [markdown]
# <img align="center" src="http://sydney.edu.au/images/content/about/logo-mono.jpg">
# <h1 align="center" style="margin-top:10px">Statistical Learning with Python</h1>
# <h2 align="center" style="margin-top:20px">Appendix 2: Making Submissions in the Kaggle Competition</h2>
# <br>
#
# In this notebook I'll show you have you to prepare the submission for the Kaggle competition. Before this, please go over the sample submission so that you can first see the format that we are trying to achieve.
#
# This notebook relies on the following imports and settings.

# %% [markdown]
# ### 1. Loading the Data

# %%
import pandas as pd
import numpy as np

train = pd.read_csv('data\CS_data.csv', index_col='HHKEY')
train.head()
# Out:
#                ZIP_CODE  REC  FRE     MON  CC_CARD    AVRG  PC_CALC20  \
# HHKEY
# 9955628074270     48328   76    1  125.96        0  125.96         11
# 9955630420476     53572  167    5  316.99        0   63.39         11
# 9955624772271     45342   96    2  175.94        0   87.97         11
# 9955600980814      2806  199    2  253.98        0  126.99         16
# 9955603247633      8060  342    1  122.00        0  122.00         16
#
#                PSWEATERS  PKNIT_TOPS  PKNIT_DRES  ...  VALPHON  WEB  MAILED  \
# HHKEY                                             ...
# 9955628074270       0.00        0.00         0.0  ...        Y    0       0
# 9955630420476       0.00        0.07         0.4  ...        Y    0       4
# 9955624772271       0.17        0.14         0.0  ...        Y    0       0
# 9955600980814       0.19        0.00         0.0  ...        Y    0      10
# 9955603247633       0.00        0.00         0.0  ...        Y    0       4
#
#                RESPONDED  RESPONSERATE     HI  LTFREDAY  CLUSTYPE  PERCRET  \
# HHKEY
# 9955628074270          0           0.0  50.61     76.00         4     0.00
# 9955630420476          1          25.0  20.39     89.66        16     0.25
# 9955624772271          0           0.0  23.17     81.50        23     0.00
# 9955600980814          2          20.0  34.76     75.87         1     0.00
# 9955603247633          0           0.0  37.47    171.00         4     0.00
#
#                RESP
# HHKEY
# 9955628074270     0
# 9955630420476     0
# 9955624772271     0
# 9955600980814     0
# 9955603247633     0
#
# [5 rows x 50 columns]

# %%
test = pd.read_csv('data\CS_kaggle.csv', index_col='HHKEY')
test.head()
# Out:
#                ZIP_CODE  REC  FRE      MON  CC_CARD   AVRG  PC_CALC20  \
# HHKEY
# 9955621115332     37373   31    1    93.00        0  93.00         11
# 9955649946385     93722  139    3   239.37        0  79.79         16
# 9955640398666     70518  247    1    75.99        0  75.99         11
# 9955648461892     91201   15   50  2929.75        1  58.59         11
# 9955604008806     10562  306    1    88.00        0  88.00         11
#
#                PSWEATERS  PKNIT_TOPS  PKNIT_DRES  ...  STORELOY  VALPHON  WEB  \
# HHKEY                                             ...
# 9955621115332       1.00    0.000000        0.00  ...      4510        Y    0
# 9955649946385       0.36    0.050000        0.00  ...      2620        N    0
# 9955640398666       0.27    0.000000        0.00  ...       859        N    0
# 9955648461892       0.06    0.003444        0.03  ...       277        Y    0
# 9955604008806       0.00    0.000000        0.00  ...       685        N    0
#
#                MAILED  RESPONDED  RESPONSERATE      HI  LTFREDAY  CLUSTYPE  \
# HHKEY
# 9955621115332       0          0           0.0  100.00     31.00        38
# 9955649946385       8          1          12.5   24.93     30.57        15
# 9955640398666       1          0           0.0   60.01    247.00        42
# 9955648461892       9          9         100.0    9.38      4.49        15
# 9955604008806       2          0           0.0  100.00    306.00        15
#
#                PERCRET
# HHKEY
# 9955621115332      0.0
# 9955649946385      0.0
# 9955640398666      0.0
# 9955648461892      0.5
# 9955604008806      0.0
#
# [5 rows x 49 columns]

# %% [markdown]
# ### 2. Fitting a Simple Model
#
# Note the difference between the report and the Kaggle competition. For the report, you need to split the main data so that you can do model evaluation. In the Kaggle competition, the whole initial dataset becomes the training data. That's because the purpose of the Kaggle competition is for you to deploy your machine learning system after careful model building, selection and evaluation, as would be the case in actual business setting.

# %%
response ='RESP'
predictors = ['FRE', 'RESPONSERATE']

y_train = train[response].to_numpy()
X_train = train[predictors].to_numpy()

# %%
from sklearn.linear_model import LogisticRegression
logit = LogisticRegression(C=np.inf, solver='lbfgs')
logit.fit(X_train, y_train)
# Out:
# LogisticRegression(C=inf, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='lbfgs',
#           tol=0.0001, verbose=0, warm_start=False)

# %% [markdown]
# ### 3. Predictions and Submission File

# %%
X_test = test[predictors].to_numpy()
y_prob = logit.predict_proba(X_test)[:,1]

# %%
submission = pd.DataFrame(y_prob, index=test.index, columns=[response])
submission.head()
# Out:
#                    RESP
# HHKEY
# 9955621115332  0.075225
# 9955649946385  0.106690
# 9955640398666  0.075225
# 9955648461892  0.990724
# 9955604008806  0.075225

# %%
# !mkdir Kaggle
submission = submission.to_csv('Kaggle\submission00.csv')
# Out:
# A subdirectory or file Kaggle already exists.

# %% [markdown]
# ### Additional Code
#
# The two cells below format the notebook for display online. Please omit them from your work.

# %%
# %%html
# <style>
# @import url('https://fonts.googleapis.com/css?family=Source+Sans+Pro|Open+Sans:800&display=swap');
# </style>
# Out:
# <style>
# @import url('https://fonts.googleapis.com/css?family=Source+Sans+Pro|Open+Sans:800&display=swap');
# </style>

# %%
from IPython.core.display import HTML
style = open('jstyle.css', "r").read()
HTML('<style>'+ style +'</style>')
# Out:
# <style>.CodeMirror pre {font-family: monospace; font-size: 12pt; line-height: 22.4px;}
#
# pre {font-family: monospace; font-size: 12pt; line-height: 22.4px;}
#
# .output_area pre {font-family: monospace; font-size: 12pt; line-height: 22.4px;}
#
# .rendered_html table {font-size: 10.5pt;}
#
# h1 {
#   font-family: 'Open Sans' !important;
#   color: #222;
#   font-size: 2.5em !important;
#   padding-bottom: 0px;
#   margin-top: 14px;
#   margin-bottom: 6px;
#   font-weight: 800 !important;
# }
#
#
# h2 {
#   font-family: 'Open Sans' !important;
#   font-size: 1.6em !important;
#   font-weight: 800 !important;
#   color: #222;
# }
#
#
# h3 {
#   font-family: 'Open Sans' !important;
#   font-size: 25px !important;
#   color: #222 !important;
#   margin-bottom: 30px !important;
#   margin-top: 25px !important;
# }
#
#
# p {
#   font-family: 'Source Sans Pro', sans-serif;
#   color: #222;
#   font-size: 19px;
#   margin-bottom: 10px;
#   margin-top:0;
#   line-height: 1.4;
# }
#
# li {
#   font-family: 'Source Sans Pro', sans-serif;
#   color: #222;
#   font-size: 19px;
#   line-height: 1.4;
# }
#
#
#
# /*code {
#      padding: 2px 4px !important;
#      font-size: 90% !important;
#      color: #c7254e !important;
#      background-color: #f9f2f4 !important;
#      border-radius: 2px !important;
#      text-decoration: none !important;
#       font-size: 90% !important;
# }
# */
#
#
# code {
#       font-size: 90% !important;
# /*      border-style: solid !important;
#       border-width: 1px !important;
#       border-color :#cccccc !important;*/
# }
#
# TT {
#       font-family: monospace;
#       font-size: 95% !important;
# }
#
#
#
# a.neutral {
#   text-decoration: none !important;
#   border-style: dotted !important;
#   border-width: 1px !important;
#   border-color :#cccccc !important;
#
# }
#
# </style>
